# %%
import ocelot

import sys
sys.path.append('../0_scripts')
import elbex_ocelot

import XTD8
# Out:
# initializing ocelot...

# %% [markdown]
# ### Run OCELOT

# %%
tws = elbex_ocelot.runOcelot(XTD8)

# %% [markdown]
# ### Plot optics

# %%
elbex_ocelot.plotAllResults(tws,XTD8)

# %% [markdown]
# ### Magnet moves to avoid shielding

# %%
import XTD8_1_shielding_moves
tws_1_shielding_moves = elbex_ocelot.runOcelot(XTD8_1_shielding_moves)
elbex_ocelot.plotAllResults(tws_1_shielding_moves,XTD8_1_shielding_moves)
