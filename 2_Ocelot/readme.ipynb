# %%
import ocelot

import sys
sys.path.append('../0_scripts')
import elbex_ocelot

import XTD8
# Out:
# initializing ocelot...

# %%
tws = elbex_ocelot.runOcelot(XTD8)

# %%
elbex_ocelot.plotAllResults(tws,XTD8)
