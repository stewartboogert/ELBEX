# %%
import pybdsim
import xtrack

import sys
sys.path.append('../3_Xsuite/')
# Out:
# initializing ocelot...

# %%
env = xtrack.Environment.from_json('../3_Xsuite/XTD8.json')
env.build_trackers()
# Out:
# Loading line from dict:   0%|          | 0/133 [00:00<?, ?it/s]
